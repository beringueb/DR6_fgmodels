# %%
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline

from fgspectra import cross as fgc
from fgspectra import frequency as fgf
from fgspectra import power as fgp

from getdist import loadMCSamples, plots

# %%
samples_MBAC = loadMCSamples('../DR6_MBAC_planck/outputs/chains/MBAC', settings={'ignore_rows':0.3})
samples_MBAC_plik = loadMCSamples('../DR6_MBAC_planck/outputs/chains/MBAC_plik', settings={'ignore_rows':0.3})
samples_MBAC_plik_dr4 = loadMCSamples('../DR6_MBAC_planck/outputs/chains/MBAC_plik_DR4_templates', settings={'ignore_rows':0.3})
samples_MBAC_plik_dr4_choi = loadMCSamples('../DR6_MBAC_planck/outputs/chains/MBAC_plik_DR4_templates_choiprior', settings={'ignore_rows':0.3})
samples_plik = loadMCSamples('../DR6_MBAC_planck/outputs/chains/plik', settings={'ignore_rows':0.3})
samples_dunkley = loadMCSamples('../dunkley/outputs/chains_2/MBAC_dunkley_templates', settings={'ignore_rows':0.3})

samples_choi_220 = loadMCSamples('../Choi/outputs/chains/DR4_220', settings={'ignore_rows':0.3})
samples_choi_220_tsz143 = loadMCSamples('../Choi/outputs/chains/DR4_220_tsz143', settings={'ignore_rows':0.3})
# Out:
# ../DR6_MBAC_planck/outputs/chains/MBAC.2.txt
# ../DR6_MBAC_planck/outputs/chains/MBAC.3.txt
# ../DR6_MBAC_planck/outputs/chains/MBAC.1.txt
# ../DR6_MBAC_planck/outputs/chains/MBAC.4.txt
# ../DR6_MBAC_planck/outputs/chains/MBAC.5.txt
# ../DR6_MBAC_planck/outputs/chains/MBAC.6.txt
# Removed 0.3 as burn in
# ../DR6_MBAC_planck/outputs/chains/MBAC_plik.1.txt
# Removed 0.3 as burn in
# ../DR6_MBAC_planck/outputs/chains/MBAC_plik_DR4_templates.3.txt
# ../DR6_MBAC_planck/outputs/chains/MBAC_plik_DR4_templates.2.txt
# ../DR6_MBAC_planck/outputs/chains/MBAC_plik_DR4_templates.1.txt
# ../DR6_MBAC_planck/outputs/chains/MBAC_plik_DR4_templates.5.txt
# ../DR6_MBAC_planck/outputs/chains/MBAC_plik_DR4_templates.4.txt
# ../DR6_MBAC_planck/outputs/chains/MBAC_plik_DR4_templates.6.txt
# Removed 0.3 as burn in
# ../Choi/outputs/chains/DR4_220.6.txt
# ../Choi/outputs/chains/DR4_220.4.txt
# ../Choi/outputs/chains/DR4_220.5.txt
# ../Choi/outputs/chains/DR4_220.1.txt
# ../Choi/outputs/chains/DR4_220.2.txt
# ../Choi/outputs/chains/DR4_220.3.txt
# Removed 0.3 as burn in

# %%
params_plots= ['a_tSZ','a_kSZ','xi','a_CIB', 'a_CIBp','beta_c','a_r_a']
g = plots.get_subplot_plotter(width_inch=20)
g.plots_1d([samples_MBAC_plik_dr4, samples_MBAC_plik_dr4_choi, samples_choi_220 ],
           params_plots, nx=3, legend_labels=["MBAC+plik (DR4 templates)", "MBAC+plik (DR4 templates + radio prior ($3.7\pm 0.24$))", "DR4 deep + MBAC 220x220"])
# Out:
# (3, 3)

# %%
print(samples_MBAC_plik_dr4.getTable(limit=1).tableTex())
# Out:
# \begin{tabular} { l  c}
#
#  Parameter &  68\% limits\\
# \hline
# {\boldmath$a_\mathrm{tSZ} $} & $4.4\pm 1.5                $\\
#
# {\boldmath$a_\mathrm{kSZ} $} & $4.2^{+2.0}_{-2.3}         $\\
#
# {\boldmath$a_\mathrm{CIB} $} & $5.05^{+0.65}_{-0.73}      $\\
#
# {\boldmath$\xi^\mathrm{tSZ \ times CIB}$} & ---                         \\
#
# {\boldmath$\beta_\mathrm{CIB-clustered}$} & $2.169\pm 0.094            $\\
#
# {\boldmath$a^\mathrm{cirrus, ACT-south}$} & $0.55\pm 0.19              $\\
#
# {\boldmath$a^\mathrm{cirrus, ACT-equa}$} & $0.80\pm 0.20              $\\
#
# {\boldmath$a_\mathrm{radio-poisson, ACT}$} & $3.08\pm 0.37              $\\
#
# {\boldmath$a_\mathrm{CIB-poisson}$} & $7.07\pm 0.42              $\\
#
# {\boldmath$y^{148}_{ACT South}$} & $1.0164\pm 0.0058          $\\
#
# {\boldmath$y^{220}_{ACT South}$} & $1.040\pm 0.014            $\\
#
# {\boldmath$y^{148}_{ACT Equa}$} & $1.0119\pm 0.0056          $\\
#
# {\boldmath$y^{220}_{ACT Equa}$} & $0.982\pm 0.011            $\\
#
# {\boldmath$a^\mathrm{poisson, Planck TT}_{100}$} & $274\pm 23                 $\\
#
# {\boldmath$a^\mathrm{poisson, Planck TT}_{143}$} & $43\pm 6                   $\\
#
# {\boldmath$a^\mathrm{poisson, Planck TT}_{217}$} & $107.2\pm 6.8              $\\
#
# {\boldmath$a^\mathrm{poisson, Planck TT}_{143 \times 217}$} & $33\pm 5                   $\\
#
# {\boldmath$a^\mathrm{dust, Planck TT}_{100}$} & $9.2\pm 1.8                $\\
#
# {\boldmath$a^\mathrm{dust, Planck TT}_{143}$} & $10.6\pm 1.8               $\\
#
# {\boldmath$a^\mathrm{dust, Planck TT}_{217}$} & $88.5\pm 6.2               $\\
#
# {\boldmath$a^\mathrm{dust, Planck TT}_{143 \times 217}$} & $16.2\pm 2.9               $\\
#
# {\boldmath$y^{100}_{Planck}$} & $0.99949\pm 0.00061        $\\
#
# {\boldmath$y^{217}_{Planck}$} & $0.99834\pm 0.00062        $\\
#
# {\boldmath$y_\mathrm{cal} $} & $1.00043\pm 0.00072        $\\
#
# $\beta_\mathrm{CIB-poisson}$ & $2.169\pm 0.094            $\\
#
# $-\log\pi                  $ & $34.1^{+1.4}_{-2.5}        $\\
#
# $-\log\pi_\mathrm{0}       $ & $31.3^{+1.2}_{-2.4}        $\\
#
# $-\log\pi_\mathrm{SZ}      $ & $2.302^{+0.067}_{-0.31}    $\\
#
# $-\log\pi_\mathrm{radio\ act}$ & $0.530^{+0.042}_{-0.57}    $\\
#
# $\chi^2                    $ & $7334.3\pm 6.0             $\\
#
# $\chi^2_\mathrm{mflike.MFLike}$ & $6563.7\pm 4.2             $\\
#
# $\chi^2_\mathrm{mflike.PlikMFLike}$ & $770.6\pm 4.3              $\\
# \hline
# \end{tabular}

# %%
ksz = fgc.FactorizedCrossSpectrum(fgf.ConstantSED(), fgp.kSZ_planck_highL())
cibp = fgc.FactorizedCrossSpectrum(fgf.ModifiedBlackBody(), fgp.PowerLaw())
radio = fgc.FactorizedCrossSpectrum(fgf.PowerLaw(), fgp.PowerLaw())
cirrus = fgc.FactorizedCrossSpectrum(fgf.ModifiedBlackBody(), fgp.PowerLaw())

tSZ_and_CIB = fgc.CorrelatedFactorizedCrossSpectrum(
    fgf.Join(fgf.ThermalSZ(), fgf.CIB()), fgp.SZxCIB_planck_highL()
)

# for testing purposes we'll also compute the tSZ and clustered CIB alone
tsz = fgc.FactorizedCrossSpectrum(fgf.ThermalSZ(), fgp.tSZ_planck_highL())
cibc = fgc.FactorizedCrossSpectrum(fgf.CIB(), fgp.CIB_planck_highL())

# %%
ell_bat, tsz_bat = np.loadtxt("../../fgspectra/fgspectra/data/cl_tsz_150_bat.dat", unpack=True)
ell_plc, tsz_plc = np.loadtxt("../../fgspectra/fgspectra/data/cl_tsz_planck.dat", unpack=True)
ell_highL, tsz_highL = np.loadtxt("../../fgspectra/fgspectra/data/cl_tsz_planck_highL.dat", unpack=True)
plt.figure(figsize=(7,7))
plt.plot(ell_bat, tsz_bat/tsz_bat[3000-2], label = "Battaglia (Dunkley et al.)")
plt.plot(ell_plc, tsz_plc/tsz_plc[3000-2], label = "Planck")
plt.plot(ell_highL, tsz_highL/tsz_highL[3000-2], label = "highL")
plt.legend()
plt.show()

# %%
ell_bat, ksz_bat = np.loadtxt("../../fgspectra/fgspectra/data/cl_ksz_bat.dat", unpack=True)
ell_plc, ksz_plc = np.loadtxt("../../fgspectra/fgspectra/data/cl_ksz_planck.dat", unpack=True)
ell_highL, ksz_highL = np.loadtxt("../../fgspectra/fgspectra/data/cl_ksz_planck_highL.dat", unpack=True)
plt.figure(figsize=(7,7))
plt.plot(ell_bat, ksz_bat/ksz_bat[3000-2], label = "Battaglia (Dunkley et al.)")
plt.plot(ell_plc, ksz_plc/ksz_plc[3000-2], label = "Planck")
plt.plot(ell_highL, ksz_highL/ksz_highL[3000-2], label = "highL")
plt.legend()
plt.show()
