# %%
from getdist import loadMCSamples, plots

# %%
samples_MBAC_90_base = loadMCSamples("../DR4_MBAC_base/outputs/chains/MBAC_90", settings={'ignore_rows':0.3})
samples_DR4_220_base = loadMCSamples("../DR4_MBAC_base/outputs/chains/DR4_220", settings={'ignore_rows':0.3})
samples_DR4_base = loadMCSamples("../DR4_MBAC_base/outputs/chains/DR4_priorcibradio", settings={'ignore_rows':0.3})
samples_MBAC_base = loadMCSamples("../DR4_MBAC_base/outputs/chains/MBAC", settings={'ignore_rows':0.3})
samples_DR4_prior = loadMCSamples("../DR4_MBAC_base/outputs/chains/DR4_priorsamp", settings={'ignore_rows':0.3})
# Out:
# ../DR4_MBAC_base/outputs/chains/MBAC.2.txt
# ../DR4_MBAC_base/outputs/chains/MBAC.3.txt
# ../DR4_MBAC_base/outputs/chains/MBAC.1.txt
# ../DR4_MBAC_base/outputs/chains/MBAC.4.txt
# ../DR4_MBAC_base/outputs/chains/MBAC.5.txt
# ../DR4_MBAC_base/outputs/chains/MBAC.6.txt
# Removed 0.3 as burn in

# %%
params = ['a_tSZ', 'a_kSZ','a_CIB','a_CIBp',
          'a_r_a','a_r_aw','beta_c', 'xi', 
          'a_gtt_aw', 'a_gtt_ad', 'a_gtt_ae', 'a_gtt_as',
         ]

g = plots.get_subplot_plotter(width_inch=20)
g.plots_1d([samples_DR4_220_base,samples_DR4_base, samples_MBAC_90_base, samples_MBAC_base],
           params, nx=4, legend_labels=["DR4 + MBAC 220x220", "DR4 only", "MBAC + DR4 90x90",  "MBAC only"])
# Out:
# (4, 3)

# %%
print(samples_DR4_base.getTable(limit=1).tableTex())
# Out:
# \begin{tabular} { l  c}
#
#  Parameter &  68\% limits\\
# \hline
# {\boldmath$a^\mathrm{cirrus, ACT-DR4-deep}$} & $2.78\pm 0.45              $\\
#
# {\boldmath$a^\mathrm{cirrus, ACT-DR4-wide}$} & $8.72\pm 0.30              $\\
#
# {\boldmath$a_\mathrm{radio-poisson, ACT-deep}$} & $3.76\pm 0.23              $\\
#
# {\boldmath$a_\mathrm{radio-poisson, ACT-wide}$} & $22.43\pm 0.32             $\\
#
# {\boldmath$a_\mathrm{CIB-poisson}$} & $6.53\pm 0.37              $\\
#
# {\boldmath$a_\mathrm{tSZ} $} & $5.28^{+0.67}_{-0.56}      $\\
#
# {\boldmath$a_\mathrm{kSZ} $} & $< 0.767                   $\\
#
# {\boldmath$a_\mathrm{CIB} $} & $3.11\pm 0.73              $\\
#
# {\boldmath$\xi^\mathrm{tSZ \ times CIB}$} & $> 0.139                   $\\
#
# {\boldmath$\beta_\mathrm{CIB-clustered}$} & $2.92^{+0.32}_{-0.55}      $\\
#
# $\beta_\mathrm{CIB-poisson}$ & $2.92^{+0.32}_{-0.55}      $\\
#
# $-\log\pi                  $ & $36.1^{+1.5}_{-2.6}        $\\
#
# $-\log\pi_\mathrm{radio\ act}$ & $1.54^{+0.54}_{-1.2}       $\\
#
# $-\log\pi_\mathrm{cib\ act}$ & $3.12^{+0.67}_{-2.2}       $\\
#
# $-\log\pi_\mathrm{cirrus\ DR4\ deep}$ & $0.612^{+0.043}_{-0.54}    $\\
#
# $-\log\pi_\mathrm{cirrus\ DR4\ wide}$ & $0.240^{+0.032}_{-0.58}    $\\
#
# $\chi^2                    $ & $-5579.4\pm 4.6            $\\
#
# $\chi^2_\mathrm{mflike.MFLike}$ & $-5579.4\pm 4.6            $\\
# \hline
# \end{tabular}
