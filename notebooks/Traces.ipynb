# %%
from getdist import loadMCSamples, plots
import matplotlib.pyplot as plt

# %%
params_common = ['a_tSZ','a_kSZ','a_CIB','xi','beta_c']
params_highL = ['a_gtt_as','a_gtt_ae','aps_148','aps_218','aps_90','aps_150',
                'aps_220','rpsa','rps0','rps1','rps2','cal_acts_148',
                'cal_acts_220','cal_acte_148','cal_acte_220','cal_sptg_90','cal_sptg_150','cal_sptg_220']
params_highL_reichardt = ['a_tSZ','a_kSZ','a_CIB','xi','beta_c','a_gtt_as',
                          'a_gtt_ae', 'a_gtt_spt','aps_148','aps_218','rpsa',
                          'beta_r', 'a_r_s', 'a_CIBp','a_CIB_2H', 'a_CIB_1H',
                          'cal_acte_148','cal_acte_220','cal_sptr_90','cal_sptr_150','cal_sptr_220']
params_plik = ['ps_A_100_100','ps_A_143_143','ps_A_217_217','ps_A_143_217',
               'gal545_A_100','gal545_A_143','gal545_A_217','gal545_A_143_217',
               'calib_100T','calib_217T','A_planck']

# %%
samples = loadMCSamples("../original/outputs/chains_2/MBAC_reichardt_fixedcosmo")
# Out:
# ../original/outputs/chains_2/MBAC_reichardt_fixedcosmo.1.txt
# Removed no burn in

# %%
for i, param in enumerate(params_highL_reichardt):
    plt.figure()
    plt.plot(samples[param])
    plt.ylabel(param)
plt.show()
# Out:
# /var/folders/jj/zmth4r4x6m9185fq4zh2375h0000gq/T/ipykernel_26691/862023615.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure()
