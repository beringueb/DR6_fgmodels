# %%
from getdist import loadMCSamples, plots
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
samples_r_base = loadMCSamples("../DR6_modelling_base/outputs/chains/reichardt", settings={'ignore_rows':0.3})
samples_a_base = loadMCSamples("../DR6_modelling_base/outputs/chains/MBAC", settings={'ignore_rows':0.3})
samples_ar_base = loadMCSamples("../DR6_modelling_base/outputs/chains/MBAC_reichardt", settings={'ignore_rows':0.3})

params = ['a_tSZ', 'a_kSZ','a_CIB','a_gtt_spt', 'a_gtt_ae', 'a_gtt_as',
          'a_r_s', 'a_r_a', 'a_CIBp','beta_c', 'cal_acts_148', 'cal_acts_220', 
          'cal_acte_148', 'cal_acte_220','cal_sptr_90','cal_sptr_150','cal_sptr_220']

g = plots.get_subplot_plotter(width_inch=20)
g.plots_1d([samples_ar_base, samples_r_base, samples_a_base],
           params, nx=4, legend_labels=["MBAC+ Reichardt (base)",
                                        "Reichardt (base)",
                                        "MBAC (base)"])
# Out:
# WARNING:root:auto bandwidth for cal_acts_220 very small or failed (h=0.00038793383585038546,N_eff=6777.182368120174). Using fallback (h=0.06819582521088165)
# (4, 5)

# %%
samples_r_betac_betap = loadMCSamples("../DR6_modelling_betac-betap/outputs/chains/reichardt", settings={'ignore_rows':0.3})
samples_a_betac_betap = loadMCSamples("../DR6_modelling_betac-betap/outputs/chains/MBAC", settings={'ignore_rows':0.3})
samples_ar_betac_betap = loadMCSamples("../DR6_modelling_betac-betap/outputs/chains/MBAC_reichardt", settings={'ignore_rows':0.3})

params = ['a_tSZ', 'a_kSZ','a_CIB','a_gtt_spt', 'a_gtt_ae', 'a_gtt_as',
          'a_r_s', 'a_r_a', 'a_CIBp','beta_c', 'beta_p', 'cal_acts_148', 'cal_acts_220', 
          'cal_acte_148', 'cal_acte_220','cal_sptr_90','cal_sptr_150','cal_sptr_220']

g = plots.get_subplot_plotter(width_inch=20)
g.plots_1d([samples_ar_betac_betap, samples_r_betac_betap, samples_a_betac_betap],
           params, nx=4, legend_labels=["MBAC+ Reichardt (betac_betap)",
                                        "Reichardt (betac_betap)",
                                        "MBAC (betac_betap)"])
# Out:
# ../DR6_modelling_betac-betap/outputs/chains/reichardt.1.txt
# Removed 0.3 as burn in
# ../DR6_modelling_betac-betap/outputs/chains/MBAC.1.txt
# Removed 0.3 as burn in
# ../DR6_modelling_betac-betap/outputs/chains/MBAC_reichardt.1.txt
# Removed 0.3 as burn in
# WARNING:root:auto bandwidth for cal_acts_220 very small or failed (h=0.0003829514894862633,N_eff=11498.326045457452). Using fallback (h=0.06202327491827339)
# (4, 5)

# %%
samples_r_betar = loadMCSamples("../DR6_modelling_betar/outputs/chains/reichardt", settings={'ignore_rows':0.3})
samples_a_betar = loadMCSamples("../DR6_modelling_betar/outputs/chains/MBAC", settings={'ignore_rows':0.3})
samples_ar_betar = loadMCSamples("../DR6_modelling_betar/outputs/chains/MBAC_reichardt", settings={'ignore_rows':0.3})

params = ['a_tSZ', 'a_kSZ','a_CIB','a_gtt_spt', 'a_gtt_ae', 'a_gtt_as',
          'a_r_s', 'a_r_a', 'a_CIBp','beta_c', 'beta_p', 'cal_acts_148', 'cal_acts_220', 
          'cal_acte_148', 'cal_acte_220','cal_sptr_90','cal_sptr_150','cal_sptr_220']

g = plots.get_subplot_plotter(width_inch=20)
g.plots_1d([samples_ar_betar, samples_r_betar, samples_a_betar],
           params, nx=4, legend_labels=["MBAC+ Reichardt (betar)",
                                        "Reichardt (betar)",
                                        "MBAC (betar)"])
# Out:
# ../DR6_modelling_betar/outputs/chains/reichardt.1.txt
# Removed 0.3 as burn in
# ../DR6_modelling_betar/outputs/chains/MBAC.1.txt
# Removed 0.3 as burn in
# ../DR6_modelling_betar/outputs/chains/MBAC_reichardt.1.txt
# Removed 0.3 as burn in
# WARNING:root:auto bandwidth for cal_acts_220 very small or failed (h=0.00037546211923410996,N_eff=10044.797690435718). Using fallback (h=0.06348603866488087)
# WARNING:root:auto bandwidth for cal_acte_220 very small or failed (h=0.00041069854884931,N_eff=10186.237128846738). Using fallback (h=0.06282567682935258)
# (4, 5)
