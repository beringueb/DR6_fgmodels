# %%
from getdist import loadMCSamples, plots

# %%
samples_agp_common = loadMCSamples("../common_templates/outputs/chains/MBAC_george_plik_fixedcosmo", settings={'ignore_rows':0.3})
samples_ag_common = loadMCSamples("../common_templates/outputs/chains/MBAC_george_fixedcosmo", settings={'ignore_rows':0.3})
samples_p_common = loadMCSamples("../common_templates/outputs/chains/plik_fixedcosmo", settings={'ignore_rows':0.3})

samples_agp_original = loadMCSamples("../original/outputs/chains/MBAC_george_plik_fixedcosmo", settings={'ignore_rows':0.3})
samples_ag_original = loadMCSamples("../original/outputs/chains/MBAC_george_fixedcosmo", settings={'ignore_rows':0.3})
samples_p_original = loadMCSamples("../original/outputs/chains/plik_fixedcosmo", settings={'ignore_rows':0.3})

samples_arp_common = loadMCSamples("../common_templates/outputs/chains/MBAC_reichardt_plik_fixedcosmo", settings={'ignore_rows':0.3})
samples_ar_common = loadMCSamples("../common_templates/outputs/chains/MBAC_reichardt_fixedcosmo", settings={'ignore_rows':0.3})
# samples_arp_original = loadMCSamples("../original/outputs/chains/MBAC_reichardt_plik_fixedcosmo", settings={'ignore_rows':0.3})
# samples_ar_original = loadMCSamples("../original/outputs/chains/MBAC_reichardt_fixedcosmo", settings={'ignore_rows':0.3})
# Out:
# ../common_templates/outputs/chains/MBAC_reichardt_plik_fixedcosmo.1.txt
# Removed 0.3 as burn in
# ../common_templates/outputs/chains/MBAC_reichardt_fixedcosmo.1.txt
# Removed 0.3 as burn in

# %%
params_common = ['a_tSZ', 'a_kSZ','a_CIB','xi','beta_c']
params_highL = ['a_gtt_as','a_gtt_ae','aps_148','aps_218','aps_90','aps_150',
                'aps_220','rpsa','rps0','rps1','rps2','cal_acts_148',
                'cal_acts_220','cal_acte_148','cal_acte_220','cal_sptg_90','cal_sptg_150','cal_sptg_220']
params_highL_reichardt = ['a_gtt_as','a_gtt_ae','aps_148','aps_218','rpsa',
                          'T_dp', 'beta_p', 'beta_r', 'a_r', 'a_CIBp',
                          'cal_acts_148','cal_acts_220','cal_acte_148','cal_acte_220','cal_sptr_90',
                          'cal_sptr_150','cal_sptr_220']
params_plik = ['ps_A_100_100','ps_A_143_143','ps_A_217_217','ps_A_143_217',
               'gal545_A_100','gal545_A_143','gal545_A_217','gal545_A_143_217',
               'calib_100T','calib_217T','A_planck']

# %%
g = plots.get_subplot_plotter(width_inch=20)
g.plots_1d([samples_ag_common, samples_agp_common, samples_ar_common, samples_arp_common],
           params_common, nx=3, legend_labels=[ "George+MBAC (common templates)", "George+MBAC+plik (common templates)","Reichardt+MBAC (common templates)", "Reichardt+MBAC+plik (common templates)"])
# Out:
# (3, 2)

# %%
g = plots.get_subplot_plotter(width_inch=20)
g.plots_1d([samples_ar_common, samples_arp_common,],
           params_highL_reichardt, nx=6, legend_labels=[ "Reichardt+MBAC (common templates)", "Reichardt+MBAC+plik (common templates)"])
# Out:
# (6, 3)

# %%
g = plots.get_subplot_plotter(width_inch=20)
g.plots_1d([samples_agp_common, samples_p_common,
           samples_agp_original, samples_p_original],
           params_plik, nx=4, legend_labels=["George+MBAC+plik (common templates)", "plik (common templates)",
                                               "George+MBAC+plik (original)", "plik (original)"])

# %%
g = plots.get_subplot_plotter(width_inch=20)
g.plots_1d([samples_ar_common, samples_arp_common, samples_p_common,
            samples_arp_original, samples_p_original],
           params_common, nx=3, legend_labels=[ "Reichardt+MBAC (common templates)", "Reichardt+MBAC+plik (common templates)", "plik (common templates)",
                                                "Reichardt+MBAC+plik (original)", "plik (original)"])
