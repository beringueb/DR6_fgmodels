# %%
from getdist import loadMCSamples, plots

# %%
samples_agp_original = loadMCSamples("../original/outputs/chains/MBAC_george_plik_fixedcosmo", settings={'ignore_rows':0.3})
samples_ag_original = loadMCSamples("../original/outputs/chains/MBAC_george_fixedcosmo", settings={'ignore_rows':0.3})
samples_p_original = loadMCSamples("../original/outputs/chains/plik_fixedcosmo", settings={'ignore_rows':0.3})

# %%
params_common = ['a_tSZ', 'a_kSZ', 'a_CIB', 'xi', 'a_gtt_as', 'a_gtt_ae', 'aps_148', 'aps_218', 'rpsa', 'aps_90', 'aps_150',
                'aps_220', 'rps0', 'rps1', 'rps2', 'cal_acts_148', 'cal_acts_220', 'cal_acte_148', 'cal_acte_220',
                'cal_sptg_90', 'cal_sptg_150', 'cal_sptg_220']
g = plots.get_subplot_plotter(width_inch=20)
g.plots_1d([samples_ag_original, samples_agp_original, samples_p_original],
           params_common, nx=5, legend_labels=[ "George+MBAC (original modelling)", "George+MBAC+plik (original modelling)", "plik (original modelling)"])
# Out:
# (5, 5)

# %%
samples_arp_original = loadMCSamples("../original/outputs/chains/MBAC_reichardt_plik_fixedcosmo", settings={'ignore_rows':0.3})
# samples_ar_original = loadMCSamples("../original/outputs/chains/MBAC_reichardt_fixedcosmo", settings={'ignore_rows':0.3})

# %%
params_common = ['a_tSZ', 'a_kSZ', 'a_CIB', 'xi', 'a_gtt_as', 'a_gtt_ae', 'aps_148', 'aps_218', 'rpsa', 'a_CIB_2H', 'a_CIBp', 'a_r', 
                 'beta_c', 'beta_p', 'beta_r', 'cal_acts_148', 'cal_acts_220', 'cal_acte_148', 'cal_acte_220',
                 'cal_sptr_90', 'cal_sptr_150', 'cal_sptr_220']
g = plots.get_subplot_plotter(width_inch=20)
g.plots_1d([samples_arp_original],
           params_common, nx=5, legend_labels=["George+MBAC+plik (original modelling)"])
# Out:
# WARNING:root:auto bandwidth for a_kSZ very small or failed (h=0.0026740100483160618,N_eff=132.77680600700742). Using fallback (h=0.0014707385302686977)
# (5, 5)
