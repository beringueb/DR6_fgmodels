# %%
from getdist import loadMCSamples, plots

# %%
samples_choi = loadMCSamples('../Choi/outputs/chains/DR4', settings={'ignore_rows':0.3})
# Out:
# ../Choi/outputs/chains/DR4.1.txt
# Removed 0.3 as burn in

# %%
params = ['a_tSZ', 'a_kSZ','a_CIB','a_gtt_a4',
          'a_r_a', 'a_CIBp','beta_c', 'cal_adr4_90', 'cal_adr4_150', 
          'xi']

g = plots.get_subplot_plotter(width_inch=20)
g.plots_1d([samples_choi],
           params, nx=4, legend_labels=["Choi DR4"])
# Out:
# (4, 3)

# %%
print(samples_choi.getTable(limit=1).tableTex())
# Out:
# \begin{tabular} { l  c}
#
#  Parameter &  68\% limits\\
# \hline
# {\boldmath$a_\mathrm{tSZ} $} & $5.14\pm 0.95              $\\
#
# {\boldmath$a_\mathrm{kSZ} $} & $< 0.838                   $\\
#
# {\boldmath$a_\mathrm{CIB} $} & $3.74\pm 0.77              $\\
#
# {\boldmath$\xi^\mathrm{tSZ \ times CIB}$} & $> 0.118                   $\\
#
# {\boldmath$\beta_\mathrm{CIB-clustered}$} & $2.31^{+0.27}_{-0.40}      $\\
#
# {\boldmath$a^\mathrm{cirrus, ACT-DR4}$} & $2.75\pm 0.32              $\\
#
# {\boldmath$a_\mathrm{radio-poisson, ACT}$} & $3.55\pm 0.25              $\\
#
# {\boldmath$a_\mathrm{CIB-poisson}$} & $6.57\pm 0.42              $\\
#
# {\boldmath$y^{90}_{ACT DR4}$} & $0.991\pm 0.010            $\\
#
# {\boldmath$y^{150}_{ACT DR4}$} & $0.9914\pm 0.0049          $\\
#
# $\beta_\mathrm{CIB-poisson}$ & $2.31^{+0.27}_{-0.40}      $\\
#
# $-\log\pi                  $ & $18.99^{+0.79}_{-1.8}      $\\
#
# $-\log\pi_\mathrm{0}       $ & $15.780^{+0.015}_{-0.28}   $\\
#
# ...
